# %%
import folium as f

# %%
polaki=f.Map(location=[18.3708132, 84.1034252])
polaki
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
from branca.element import Figure
fig=Figure(width=550,height=350)
map1=f.Map(location=[18.3708132, 84.1034252],zoom_start=12,min_zoom=8,max_zoom=20)
fig.add_child(map1)
map1
# Out:
# <iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
# ...

# %%
lkota=f.Map(location=[18.0234, 83.1555])
lkota
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
coordinate=[[16.812246405690345, 80.8126910049282],[16.686003539988878, 80.95551326408321],[16.749135436761062, 81.13129450612016],[16.801729367146848, 81.25214411002057],
            [16.980439479960832, 81.38398004154828],[17.053976661096616, 81.60370659409446],[17.022464263781384, 81.80146049138604],[17.158979545254432, 82.08710500969607],
            [17.053976661096616, 81.72455619799486],[17.242939111793167, 82.29584523461494],[17.389776412612346, 82.55951709767038],[17.546971390165243, 82.85614794360772],
            [17.672629322388207, 82.99897020276275],[17.871408050325922, 83.39447799734589],[18.101295261200445, 83.50434127361896],[18.20569010690219, 83.63617720514668],
            [18.393040281316637, 84.01992889813201],[18.41649512353956, 84.03091522575932],[18.398252744552288, 84.05288788101394],[18.387827660394187, 84.08310028198905],[18.36176219182322, 84.12429901059146]]

# %%
fig5=Figure(height=550,width=850)
map5=f.Map(location=[18.285350287483777, 81.60553206026464],tiles='cartodbpositron',zoom_start=7)
fig5.add_child(map5)
# Out:
# <iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
# ...

# %%
f1=f.FeatureGroup("way to village")

# %%
line_1=f.vector_layers.PolyLine(coordinate,popup='<b>my village root</b>',tooltip='way to polaki',color='blue',weight=10).add_to(f1)
f1.add_to(map5)
f.LayerControl().add_to(map5)
f.Marker(location=[18.33554042268198, 83.95017710546297],popup='<strong>collage</strong>',tooltip='<strong>Padmavathi clg</strong>',icon=f.Icon(color='green',prefix='glyphicon',icon='book')).add_to(map5)
f.Marker(location=[18.30695425761176, 83.87629257245608],popup='<h3 style="color:green;">Hospital</h3>',tooltip='<strong>KIMS srikakulam</strong>',icon=f.Icon(color='purple',prefix='glyphicon',icon='header')).add_to(map5)
f.Marker(location=[17.370185278197592, 82.53819643860326],popup='<h3 style="color:blue;">D-mart</h3>',tooltip='<strong>D-mart tuni</strong>',icon=f.Icon(color='blue',prefix='glyphicon',icon='shopping-cart')).add_to(map5)
f.Marker(location=[18.39077991727785, 84.10469674294902],popup='<h3 style="color:pink;">MY Home</h3>',tooltip='<strong>My village</strong>',icon=f.Icon(color='pink',prefix='glyphicon',icon='home')).add_to(map5)
f.Marker(location=[16.783323147188216, 80.82120926018284],popup='<h3 style="color:green;">IIIT NUZVID</h3>',tooltip='<strong>Iiitttt</strong>',icon=f.Icon(color='green',prefix='glyphicon',icon='book')).add_to(map5)
f.Marker(location=[16.779958411059212, 80.87165928042769],popup='<h3 style="color:red;">Saraswathi devi tepmle</h3>',tooltip='<strong>saraswathi devi temple tukkuluru</strong>',icon=f.Icon(color='red',prefix='glyphicon',icon='bell')).add_to(map5)
f.Marker(location=[17.031655933774672, 81.72758133085306],popup='<h3 style="color:orange;">gowtham ghat</h3>',tooltip='<strong>Gwotham ghat</strong>',icon=f.Icon(color='orange',prefix='glyphicon',icon='flag')).add_to(map5)
f.Marker(location=[17.119610412372783, 81.9256785596316],popup='<h3 style="color:gray;">Hotel</h3>',tooltip='<strong>Annapurna hotel</strong>',icon=f.Icon(color='gray',prefix='glyphicon',icon='cutlery')).add_to(map5)
f.Marker(location=[17.26966043490772, 82.38452942093518],popup='<h3 style="skyblue;">RTA checkpost</h3>',tooltip='<strong>checkpost</strong>',icon=f.Icon(color='skyblue',prefix='glyphicon',icon='open')).add_to(map5)
map5
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:12: UserWarning: color argument of Icon should be one of: {'lightblue', 'orange', 'green', 'cadetblue', 'darkpurple', 'beige', 'red', 'purple', 'lightgray', 'black', 'gray', 'pink', 'lightred', 'lightgreen', 'darkred', 'white', 'darkgreen', 'blue', 'darkblue'}.
#   if sys.path[0] == '':
# <iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
# ...

# %%
f.Marker(location=[18.33554042268198, 83.95017710546297],popup='<strong>Marker3</strong>',tooltip='<strong>Click here to see Popup</strong>',icon=f.Icon(color='green',prefix='glyphicon',icon='off')).add_to(map5)
f.Marker(location=[18.30695425761176, 83.87629257245608],popup='<h3 style="color:green;">Marker2</h3>',tooltip='<strong>Click here to see Guntur</strong>',icon=f.Icon(color='purple',prefix='fa',icon='anchor')).add_to(map5)
